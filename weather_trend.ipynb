# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns; sns.set(rc={'figure.figsize':(30,10)})

# %%
weather_2019_07 = pd.read_csv("weather/unzipped/SURFACE_ASOS_131_MI_2019-07_2019-07_2019.csv")
weather_2019_07 = weather_2019_07.reset_index()

# %%
x = [x for x in range(44576)]
y_solar_rad = weather_2019_07['solar_radiation']

# %%
solar_energy = pd.read_csv("data/SolarPV_Elec_Problem.csv").reset_index()
point_num = 2975 #number of solar energy data point in July

# %%
x_s = [x for x in range(point_num)]
y_energy = solar_energy['0'][:2975]

# %%
ax = sns.lineplot(x=weather_2019_07.index, y = 'solar_radiation', data = weather_2019_07)

# %%
ax2 = sns.lineplot(x = solar_energy[:point_num].index, y = '0', data=solar_energy[:point_num])

# %%
avg_df = pd.read_csv("utils/generator/dataset/dataset.csv")

# %%
corr = avg_df.corr()

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, vmin=-1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
test = avg_df.solar_intensity.diff()

# %%
period_min = 15
weather = pd.read_csv("utils/generator/dataset/src/AVG_weather_15min.csv", index_col=1, parse_dates=True)
test1 = weather['일조(Sec)'].resample(f'{str(period_min)}T').mean().diff()
